# %% [markdown]
# # NAIRU Colombia - Exploration
#
# Este notebook contiene análisis exploratorio de datos para la estimación de la NAIRU en Colombia.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
